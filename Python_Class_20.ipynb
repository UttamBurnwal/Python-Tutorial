# %% [markdown]
# **Hyper Parameter Tunning**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier()
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.datasets import load_iris
dataset = load_iris()
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['target']= dataset.target
df.sample(5)
# Out:
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 76                 6.8               2.8  ...               1.4       1
# 142                5.8               2.7  ...               1.9       2
# 9                  4.9               3.1  ...               0.1       0
# 116                6.5               3.0  ...               1.8       2
# 34                 4.9               3.1  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
dtc= DecisionTreeClassifier()
dtc.fit(df.drop(columns=['target']), df.target)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(12,7))
plot_tree(dtc)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
dtc2= DecisionTreeClassifier(max_depth=3)
dtc2.fit(df.drop(columns=['target']), df.target)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
plt.figure(figsize=(12,7))
plot_tree(dtc2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
dtc.get_depth()
# Out:
# 5

# %%
dtc2.feature_importances_
# Out:
# array([0.        , 0.        , 0.05393633, 0.94606367])

# %%
a= np.random.RandomState(42)
a.randint(1,100, 5)
# Out:
# array([52, 93, 15, 72, 61])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %% [markdown]
# **Unsupervised Learning**

# %%
# Supervised Algo
# Input, Output --> Algo --> Model

# Unsupervised (no output)
# Input data has only input and no output
# Try to find relationship and pattern in Input itself

# %%
# Netflix - Very first time - it still shows you recommendations!!
